# %%
#Q1. Write a python program to extract the video URL of the first five videos.
#Q2. Write a python program to extract the URL of the video thumbnails of the first five videos.
#Q3. Write a python program to extract the title of the first five videos.
#Q4. Write a python program to extract the number of views of the first five videos.
#Q5. Write a python program to extract the time of posting of video for the first five videos.
#Note: Save all the data scraped in the above questions in a CSV file.

from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
import csv

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
driver.get("https://www.youtube.com/@PW-Foundation/videos")

links = driver.find_elements(By.ID, "video-title-link")
thumbnails = driver.find_elements(By.XPATH, '//a[@id="thumbnail"]/yt-image/img')
titles = driver.find_elements(By.ID, "video-title")
views = driver.find_elements(By.XPATH,'//div[@id="metadata-line"]/span[1]')
time_period = driver.find_elements(By.XPATH,'//div[@id="metadata-line"]/span[2]')

print('links:')
links_list = []
for link in links[0:5]:
    print(link.get_attribute('href'))
    links_list.append(link.get_attribute('href'))
print('\n')

print('thumbnails:')
thumb_list = []
for thumb in thumbnails[0:5]:
    print(thumb.get_attribute('src'))
    thumb_list.append(thumb.get_attribute('src'))
print('\n')

print('titles:')
titles_list = []
for title in titles[0:5]:
    print(title.text)
    titles_list.append(title.text.encode("UTF-8"))
print('\n')

print('views:')
views_list = []
for view in views[0:5]:
    print(view.text)
    views_list.append(view.text.encode("UTF-8"))
print('\n')

print('time period:')
time_list = []
for i in time_period[0:5]:
    print(i.text)
    time_list.append(i.text.encode("UTF-8"))
print('\n')

with open('image_scraper.csv', 'w', newline = '') as f:
    writer = csv.writer(f)
    writer.writerows([['Video 1', 'Video 2', 'Video 3', 'Video 4', 'Video 5'],
                      links_list, thumb_list, titles_list, views_list, time_list])
# Out:
# links:
# https://www.youtube.com/watch?v=hzwEXoQDNCs
# https://www.youtube.com/watch?v=0s6hAsFGxYE
# https://www.youtube.com/watch?v=YXRyMc_noiE
# https://www.youtube.com/watch?v=PI1obes98Zc
# https://www.youtube.com/watch?v=16fUsD0M1-I
#
#
# thumbnails:
# https://i.ytimg.com/vi/hzwEXoQDNCs/hqdefault.jpg?sqp=-oaymwEcCNACELwBSFTyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLCQV1oAuIiAQSwPO5DkYRO4nS3sTw
# https://i.ytimg.com/vi/0s6hAsFGxYE/hqdefault.jpg?sqp=-oaymwE2CNACELwBSFTyq4qpAygIARUAAIhCGAFwAcABBvABAfgB_gmAAtAFigIMCAAQARg5IGMocjAP&rs=AOn4CLAQkGBWDre0iUULVpOCUsc_5IwDcQ
# https://i.ytimg.com/vi/YXRyMc_noiE/hqdefault.jpg?sqp=-oaymwEcCNACELwBSFTyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLCECDvWKL3IcuAUJ05KS3sWYkdAbQ
# https://i.ytimg.com/vi/PI1obes98Zc/hqdefault.jpg?sqp=-oaymwEcCNACELwBSFTyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLBgVolEc_cMuT4WDvGXE-b2_fV5QA
# https://i.ytimg.com/vi/16fUsD0M1-I/hqdefault.jpg?sqp=-oaymwEcCNACELwBSFTyq4qpAw4IARUAAIhCGAFwAcABBg==&rs=AOn4CLDq5HNvB6ace0muPrvybtSDVmggjg
#
#
# titles:
# Aarambh Batch 2024 | For CBSE Class 11th Commerce | Biggest Launch🔥
# India's NO.1 Batch for Class 10th - UDAAN ⚡ Launching Today !! Check Description.
# India's Biggest Scholarship Test for Classes 8th to 12th !! 🔥🔥 || PW SAT 2023 ⚡💥
# How to score 95%+ in class 10th? Complete year Powerful Strategy!!
# Last 4 Days Left For SST Exam || How To Manage to Score 80/80 in Boards || Class-10th
#
#
# views:
# 18 waiting
# 52K views
# 59K views
# 241K views
# 69K views
#
#
# time period:
# Premieres 3/25/23, 7:00 PM
# 2 days ago
# 3 days ago
# 2 weeks ago
# 2 weeks ago
